# %%
import cv2

# %%
img = cv2.imread('test.jpg',0)
cv2.imshow('image_display',img)

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('SignVideos/no-problem.mov')

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('SignVideos/no-problem.mov')

while(cap.isOpened()):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-19fdcf277a53> in <module>()
#       4     ret, frame = cap.read()
#       5
# ----> 6     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       7
#       8     cv2.imshow('frame',gray)
#
# error: /Users/jenkins/miniconda/1/x64/conda-bld/conda_1486588158526/work/opencv-3.1.0/modules/imgproc/src/color.cpp:7456: error: (-215) scn == 3 || scn == 4 in function ipp_cvtColor

# %%
# Edge Detection

import numpy as np

filename = 'download.jpeg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

img = cv2.imread('download.jpeg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

corners = cv2.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.int0(corners)

for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,255,-1)

plt.imshow(img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x111999710>, None)

# %%
import cv2
import numpy as np
import os

counter = 11
# Playing video from file:

while ( counter<=31) :
    cap = cv2.VideoCapture('SignVideos/File' + str(counter) + '.mov')

    try:
        if not os.path.exists('SignedVideoFrames/File' + str(counter)):
            os.makedirs('SignedVideoFrames/File' + str(counter))
    except OSError:
        print ('Error: Creating directory of data')

    currentFrame = 0

    ret, frame = cap.read()
    while(ret):
        # Capture frame-by-frame

        # Saves image of the current frame in jpg file
        name = './SignedVideoFrames/File' + str(counter) + '/frame' + str(currentFrame) + '.jpg'
        print ('Creating...' + name)
        cv2.imwrite(name, frame)

        # To stop duplicate images
        currentFrame += 1
        ret, frame = cap.read()

    # When everything done, release the capture
    cap.release()
    cv2.destroyAllWindows()
    counter = counter + 1
# Out:
# Creating..../SignedVideoFrames/File11/frame0.jpg
# Creating..../SignedVideoFrames/File11/frame1.jpg
# Creating..../SignedVideoFrames/File11/frame2.jpg
# Creating..../SignedVideoFrames/File11/frame3.jpg
# Creating..../SignedVideoFrames/File11/frame4.jpg
# Creating..../SignedVideoFrames/File11/frame5.jpg
# Creating..../SignedVideoFrames/File11/frame6.jpg
# Creating..../SignedVideoFrames/File11/frame7.jpg
# Creating..../SignedVideoFrames/File11/frame8.jpg
# Creating..../SignedVideoFrames/File11/frame9.jpg
# Creating..../SignedVideoFrames/File11/frame10.jpg
# Creating..../SignedVideoFrames/File11/frame11.jpg
# Creating..../SignedVideoFrames/File11/frame12.jpg
# Creating..../SignedVideoFrames/File11/frame13.jpg
# Creating..../SignedVideoFrames/File11/frame14.jpg
# Creating..../SignedVideoFrames/File11/frame15.jpg
# Creating..../SignedVideoFrames/File11/frame16.jpg
# Creating..../SignedVideoFrames/File11/frame17.jpg
# Creating..../SignedVideoFrames/File11/frame18.jpg
# ...

# %%
import cv2
import numpy as np
import os

# Playing video from file:

#labels = ['again','cool','dont know','fingerspell','from','have to','her his','here','learning','leave','live','mine','now','oh i see','our','she he','sign','their','them','we','what','when','where','who','why','you','your']
labels = ['again','cool','dont know','fingerspell','from','have to','her his','their','why','your']
for label in labels:
    cap = cv2.VideoCapture('/Users/pkaur/tensorflow/SignLanguage/SignDataTest/videos/' + label + '.mov')

    try:
        if not os.path.exists('/Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/' + label):
            os.makedirs('/Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/' + label)
    except OSError:
        print ('Error: Creating directory of data')

    currentFrame = 0

    ret, frame = cap.read()
    while(ret):
        # Capture frame-by-frame

        # Saves image of the current frame in jpg file
        name = '/Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/' + label + '/PavFile' + str(currentFrame) + '.jpg'
        print ('Creating...' + name)
        cv2.imwrite(name, frame)

        # To stop duplicate images
        currentFrame += 1
        ret, frame = cap.read()

    # When everything done, release the capture
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile0.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile1.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile2.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile3.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile4.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile5.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile6.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile7.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile8.jpg
# Creating.../Users/pkaur/tensorflow/SignLanguage/SignDataTest/TestSet3/again/PavFile9.jpg
# ...

# %%
# Frame rearrangement

import cv2
import numpy as np
import os

# Playing video from file:
counter = 124

for c in range(124,0,-1):
    
    name_one = '/Users/pkaur/Downloads/PayelFrames/their/PTwo' + str(c) + '.jpg'
    cap = cv2.imread(name_one)
    print ('Reading...'+ name_one)
    name = '/Users/pkaur/Downloads/PayelFrames/theirnew/PTwo' + str(counter) + '.jpg'
    print ('Creating...' + name)
    cv2.imwrite(name, cap)

    cv2.destroyAllWindows()
    counter = counter + 1
# Out:
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo124.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo124.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo123.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo125.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo122.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo126.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo121.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo127.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo120.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo128.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo119.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo129.jpg
# Reading.../Users/pkaur/Downloads/PayelFrames/their/PTwo118.jpg
# Creating.../Users/pkaur/Downloads/PayelFrames/theirnew/PTwo130.jpg
# ...
